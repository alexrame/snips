# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
results = pd.io.pickle.read_pickle('results/results_df_last.pkl')
ordered_cols = [
    'n_round',
    'early_stopping',
    'bst:max_depth',
    'bst:eta',
    'bst:subsample',
    'bst:colsample_bytree',
    'ntrees',
    'score',
    'best_ntrees',
    'best_score',
]
results = results[ordered_cols]
len(results)
#results=results.sort(['best_score']).iloc[:10]
# Out:
# 100

# %%
df = results
df
# Out:
#     n_round  early_stopping  bst:max_depth   bst:eta  bst:subsample  \
# 0       800             100             17  0.100158       0.520739
# 1       800             100             18  0.093629       0.901434
# 2       800             100             26  0.043463       0.898369
# 3       800             100             21  0.132247       0.966850
# 4       800             100             21  0.053184       0.754955
# 5       800             100             11  0.197191       0.882263
# 6       800             100             11  0.207988       0.886666
# 7       800             100             13  0.134239       0.839309
# 8       800             100             16  0.138753       0.594383
# 9       800             100             23  0.018359       0.616387
# 10      800             100             20  0.152163       0.623131
# 11      800             100             17  0.194788       0.709124
# 12      800             100             16  0.196327       0.553802
# ...

# %%
df.iloc[0]['bst:eta']
# Out:
# 0.11551197421096039

# %%
fig = plt.figure()
plt.scatter(df['bst:eta'], df['best_score'])
plt.xlabel('learningRate', fontsize=16)
plt.ylabel('logloss score', fontsize=16)
plt.show()

# %%
maxDepthTree

# %%
plt.scatter(df['bst:max_depth'], df['best_score'])

# %%
plt.scatter(df['bst:subsample'], df['best_score'])

# %%
plt.scatter(df['bst:colsample_bytree'], df['best_score'])

# %%
plt.scatter(df['best_ntrees'], df['best_score'])

# %%
trX,trY,teX,teY = getData(oh=0)
